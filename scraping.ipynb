# %%
from dputils.scrape import Scraper, Tag

# %%
sc=Scraper('https://www.javatpoint.com/')

# %%
print(sc.soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://static.javatpoint.com/images/favicon2.png" rel="SHORTCUT ICON"/>
# <title>Tutorials List - Javatpoint</title>
# <meta content="javatpoint, java tutorial, core java tutorial, beginners, professionals" name="keywords">
# <meta content="Tutorials, Free Online Tutorials, Javatpoint provides tutorials and interview questions of all technology like java tutorial, android, java frameworks, javascript, ajax, core java, sql, python, php, c language etc. for beginners and professionals." name="description"/>
# <link href="https://clients1.google.com" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://static.javatpoint.com" rel="preconnect"/><link href="https://www.google.com" rel="preconnect"/><link href="https://feedify.net" rel="preconnect"/>
# ...

# %% [markdown]
# ### Flipkart

# %%
url = 'https://www.flipkart.com/search?q=bags'
sc=Scraper(url)
target=Tag('div',cls='_1YokD2 _3Mm1Gg')
items=Tag('div',cls='_1xHGtK _373qXS')
# to be scraped
brand=Tag('div',cls='_2WkVRV')
title=Tag('a',cls='IRpwTa')
sprice=Tag('div')
