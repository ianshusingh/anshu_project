# %% [markdown]
# - math module
# - random module
# - os module
# - datetime module
# - import library
# - from library import func1, func2, func3
# - import library as lib # alias
#
# from library import {
#     fun1, fun2, fun3
# }

# %%
import math

# %%
math.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
math.degrees(math.pi)
# Out:
# 180.0

# %%
from random import randint, random, choice

# %%
result = randint(1, 100)
print(f'I got {result}')
# Out:
# I got 14

# %%
random()
# Out:
# 0.14367583865579292

# %%
choice([12, 22, 33, 44, 55])
# Out:
# 22

# %%
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\ANSHU\OneDrive\Documents\anshu_project

# %%
base_dir = os.getcwd()

# %%
contents = os.listdir() # get the content of the current directory
print(contents)
# Out:
# ['.git', 'basics', 'dice_simulator.py', 'dict.ipynb', 'libraries.ipynb', 'list_1.ipynb', 'questions.ipynb', 'tuple.ipynb']

# %%
programs = os.listdir('C:\Program Files')
print(programs)
# Out:
# ['Adobe', 'AMD', 'Android', 'Common Files', 'desktop.ini', 'Git', 'Google', 'HP', 'HPCommRecovery', 'Internet Explorer', 'Java', 'LibreOffice', 'Microsoft Office', 'Microsoft Office 15', 'Microsoft OneDrive', 'Microsoft Update Health Tools', 'Microvirt', 'ModifiableWindowsApps', 'MSBuild', 'NVIDIA Corporation', 'Online Services', 'Portrait Displays', 'Reference Assemblies', 'Uninstall Information', 'UNP', 'Windows Defender', 'Windows Mail', 'Windows Media Player', 'Windows NT', 'Windows Photo Viewer', 'Windows Sidebar', 'WindowsApps', 'WindowsPowerShell']

# %%
for path, folders, files in os.walk('C:\Program Files\Git'):
    print(f'{folders} | {files}')
# Out:
# ['bin', 'cmd', 'dev', 'etc', 'mingw64', 'tmp', 'usr'] | ['git-bash.exe', 'git-cmd.exe', 'LICENSE.txt', 'ReleaseNotes.html', 'unins000.dat', 'unins000.exe', 'unins000.msg']
# [] | ['bash.exe', 'git.exe', 'sh.exe']
# [] | ['git-gui.exe', 'git-lfs.exe', 'git.exe', 'gitk.exe', 'scalar.exe', 'start-ssh-agent.cmd', 'start-ssh-pageant.cmd']
# ['mqueue', 'shm'] | ['fd', 'stderr', 'stdin', 'stdout']
# [] | []
# [] | []
# ['pkcs11', 'pki', 'profile.d', 'ssh'] | ['bash.bashrc', 'bash.bash_logout', 'DIR_COLORS', 'docx2txt.config', 'fstab', 'gitattributes', 'gitconfig', 'hosts', 'inputrc', 'install-options.txt', 'msystem', 'mtab', 'nanorc', 'networks', 'nsswitch.conf', 'package-versions.txt', 'profile', 'protocols', 'services', 'tigrc', 'vimrc']
# [] | ['pkcs11.conf.example']
# ['ca-trust'] | []
# ['extracted'] | []
# ['java', 'openssl', 'pem'] | []
# [] | ['cacerts']
# [] | ['ca-bundle.trust.crt']
# [] | ['email-ca-bundle.pem', 'objsign-ca-bundle.pem', 'tls-ca-bundle.pem']
# ...

# %%
os.path.exists('C:\Program Files\Microsoft VS Code')
# Out:
# False
